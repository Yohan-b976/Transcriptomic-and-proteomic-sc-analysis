# %%
# %pip install pydeseq2
# Out:
# Collecting pydeseq2
#   Downloading pydeseq2-0.5.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: anndata>=0.8.0 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from pydeseq2) (0.11.3)
# Collecting formulaic>=1.0.2 (from pydeseq2)
#   Downloading formulaic-1.1.1-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from pydeseq2) (2.1.3)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from pydeseq2) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from pydeseq2) (1.6.1)
# Requirement already satisfied: scipy>=1.11.0 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from pydeseq2) (1.15.2)
# Collecting formulaic-contrasts>=0.2.0 (from pydeseq2)
#   Downloading formulaic_contrasts-1.0.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: matplotlib>=3.6.2 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from pydeseq2) (3.10.1)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from anndata>=0.8.0->pydeseq2) (1.11)
# Requirement already satisfied: h5py>=3.7 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from anndata>=0.8.0->pydeseq2) (3.13.0)
# Requirement already satisfied: natsort in c:\users\test\anaconda3\envs\deg\lib\site-packages (from anndata>=0.8.0->pydeseq2) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from anndata>=0.8.0->pydeseq2) (24.2)
# Collecting interface-meta>=1.2.0 (from formulaic>=1.0.2->pydeseq2)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from formulaic>=1.0.2->pydeseq2) (4.12.2)
# Collecting wrapt>=1.17.0rc1 (from formulaic>=1.0.2->pydeseq2)
#   Downloading wrapt-1.17.2-cp313-cp313-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: session-info in c:\users\test\anaconda3\envs\deg\lib\site-packages (from formulaic-contrasts>=0.2.0->pydeseq2) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from matplotlib>=3.6.2->pydeseq2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from matplotlib>=3.6.2->pydeseq2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from matplotlib>=3.6.2->pydeseq2) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from matplotlib>=3.6.2->pydeseq2) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from matplotlib>=3.6.2->pydeseq2) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from matplotlib>=3.6.2->pydeseq2) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from matplotlib>=3.6.2->pydeseq2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from pandas>=1.4.0->pydeseq2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from pandas>=1.4.0->pydeseq2) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from scikit-learn>=1.1.0->pydeseq2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from scikit-learn>=1.1.0->pydeseq2) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6.2->pydeseq2) (1.17.0)
# Requirement already satisfied: stdlib-list in c:\users\test\anaconda3\envs\deg\lib\site-packages (from session-info->formulaic-contrasts>=0.2.0->pydeseq2) (0.11.1)
# Downloading pydeseq2-0.5.0-py3-none-any.whl (46 kB)
# Downloading formulaic-1.1.1-py3-none-any.whl (115 kB)
# Downloading formulaic_contrasts-1.0.0-py3-none-any.whl (10 kB)
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Downloading wrapt-1.17.2-cp313-cp313-win_amd64.whl (38 kB)
# Installing collected packages: wrapt, interface-meta, formulaic, formulaic-contrasts, pydeseq2
# Successfully installed formulaic-1.1.1 formulaic-contrasts-1.0.0 interface-meta-1.3.0 pydeseq2-0.5.0 wrapt-1.17.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import scanpy as sc
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats

# %%
SEACell_ad = sc.read('G:/Data processing pipeline 0.1 Yohan/scRNA/Output/ad_seacell_wlabels/ad_seacell_wlabels.h5ad')

# %%
SEACell_ad
# Out:
# AnnData object with n_obs × n_vars = 320 × 13893
#     obs: 'Purity', 'Cell_type', 'Compactness', 'separation', 'sample', 'dpi', 'Id'
#     layers: 'raw'

# %%
SEACell_ad.X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 3595367 stored elements and shape (320, 13893)>

# %%
print(SEACell_ad.X[:5, :5].toarray())
# Out:
# [[49.  5. 10.  2. 70.]
#  [41.  6. 14.  3. 75.]
#  [17.  0. 10.  0. 26.]
#  [48.  7. 38.  0. 94.]
#  [50.  5.  9.  0. 65.]]

# %% [markdown]
# # DESeq

# %%
# %pip install sanbomics
# Out:
# Collecting sanbomics
#   Downloading sanbomics-0.1.0-py3-none-any.whl.metadata (887 bytes)
# Requirement already satisfied: pandas>=1.0 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from sanbomics) (2.2.3)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from sanbomics) (2.1.3)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from sanbomics) (3.10.1)
# Requirement already satisfied: seaborn in c:\users\test\anaconda3\envs\deg\lib\site-packages (from sanbomics) (0.13.2)
# Collecting adjustText>=0.7.3 (from sanbomics)
#   Downloading adjustText-1.3.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: scipy>=1.9.1 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from sanbomics) (1.15.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from matplotlib>=3.4->sanbomics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from matplotlib>=3.4->sanbomics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from matplotlib>=3.4->sanbomics) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from matplotlib>=3.4->sanbomics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from matplotlib>=3.4->sanbomics) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from matplotlib>=3.4->sanbomics) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from matplotlib>=3.4->sanbomics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from matplotlib>=3.4->sanbomics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from pandas>=1.0->sanbomics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from pandas>=1.0->sanbomics) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.4->sanbomics) (1.17.0)
# Downloading sanbomics-0.1.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 11.4 MB/s eta 0:00:00
# Downloading adjustText-1.3.0-py3-none-any.whl (13 kB)
# Installing collected packages: adjustText, sanbomics
# Successfully installed adjustText-1.3.0 sanbomics-0.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sanbomics.plots import volcano

# %%
SEACell_ad.obs['Cell_type'].unique()
# Out:
# ['Superbasal', 'Club cells', 'Goblet cells', 'Ciliated cells', 'Unk3', ..., 'Undetermined serous cells', 'Unk2', 'Ionocytes', 'Deuterosomal', 'Unk1']
# Length: 11
# Categories (11, object): ['Basal cells', 'Ciliated cells', 'Club cells', 'Deuterosomal', ..., 'Undetermined serous cells', 'Unk1', 'Unk2', 'Unk3']

# %% [markdown]
# # All the graphes

# %%
cell_type = ['Superbasal', 'Club cells', 'Goblet cells', 'Ciliated cells','Undetermined serous cells', 'Basal cells']

# %%
Deseq2_analysis = {}
for _ in cell_type:
    for i in SEACell_ad.obs['dpi'].unique():
        
        SEACell_ad_subset = SEACell_ad[(SEACell_ad.obs['Cell_type'] == _) & (SEACell_ad.obs['dpi'] == i)]
        
        counts = pd.DataFrame(SEACell_ad_subset.X.toarray(), columns = SEACell_ad_subset.var_names)
        dds = DeseqDataSet(
            counts = counts,
            metadata=SEACell_ad_subset.obs,
            design_factors="sample")
        dds.deseq2()
        stat_res = DeseqStats(dds, contrast=('sample', 'Inf', 'Mock'))
        print(stat_res.summary())
        diff_expr  = stat_res.results_df
        Deseq2_analysis[f'{_}_{i}'] = diff_expr





        
        diff_expr['symbol'] = SEACell_ad.var_names
        volcano(diff_expr)
        print(f'Volcano plot of the cell type: {_} and dpi: {i}')
# Out:
# C:\Users\test\AppData\Local\Temp\ipykernel_17156\3859081819.py:8: DeprecationWarning: design_factors is deprecated and will soon be removed.Please consider providing a formulaic formula using the design argumentinstead.
#   dds = DeseqDataSet(
# Fitting size factors...
# ... done in 0.03 seconds.
# Using None as control genes, passed at DeseqDataSet initialization
# Fitting dispersions...
# ... done in 2.22 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.46 seconds.
#
# Fitting MAP dispersions...
# ... done in 2.73 seconds.
#
# Fitting LFCs...
# ... done in 1.41 seconds.
#
# Calculating cook's distance...
# ... done in 0.04 seconds.
#
# Replacing 65 outlier genes.
#
# Fitting dispersions...
# ... done in 0.03 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.03 seconds.
#
# Fitting LFCs...
# ... done in 0.03 seconds.
#
# Running Wald tests...
# ... done in 1.03 seconds.
# Log2 fold change & Wald test p-value: sample Inf vs Mock
#           baseMean  log2FoldChange     lfcSE      stat    pvalue      padj
# NOC2L    31.471831        0.359553  0.180917  1.987394  0.046879  0.319256
# KLHL17    2.588179       -0.190397  0.348537 -0.546275  0.584877  0.867594
# PLEKHN1  20.088842        0.170896  0.364821  0.468438  0.639471  0.890774
# PERM1     0.059331       -0.128187  3.096594 -0.041396  0.966980       NaN
# HES4     46.640275        0.565515  0.146871  3.850434  0.000118  0.007524
# ...            ...             ...       ...       ...       ...       ...
# EGFP      0.495947        2.360540  1.195484  1.974547  0.048320       NaN
# REPLI     0.926888        3.208850  1.155676  2.776600  0.005493       NaN
# GLYCO     0.739732        2.916351  1.064460  2.739746  0.006149       NaN
# MEMB      1.572580        3.968030  0.992473  3.998123  0.000064  0.004723
# NUCL      1.454729        3.714877  0.868323  4.278219  0.000019  0.001759
#
# [13893 rows x 6 columns]
# None
# Volcano plot of the cell type: Superbasal and dpi: J3
# C:\Users\test\AppData\Local\Temp\ipykernel_17156\3859081819.py:8: DeprecationWarning: design_factors is deprecated and will soon be removed.Please consider providing a formulaic formula using the design argumentinstead.
#   dds = DeseqDataSet(
# Fitting size factors...
# ... done in 0.04 seconds.
# Using None as control genes, passed at DeseqDataSet initialization
# Fitting dispersions...
# ... done in 2.25 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.47 seconds.
#
# Fitting MAP dispersions...
# ... done in 2.92 seconds.
#
# Fitting LFCs...
# ... done in 1.51 seconds.
#
# Calculating cook's distance...
# ... done in 0.06 seconds.
#
# Replacing 162 outlier genes.
#
# Fitting dispersions...
# ... done in 0.10 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.07 seconds.
#
# Fitting LFCs...
# ... done in 0.08 seconds.
#
# Running Wald tests...
# ... done in 1.07 seconds.
# Log2 fold change & Wald test p-value: sample Inf vs Mock
#           baseMean  log2FoldChange     lfcSE      stat    pvalue      padj
# NOC2L    18.785962        0.153642  0.143202  1.072903  0.283315  0.669033
# KLHL17    2.197285        0.500303  0.313204  1.597374  0.110182       NaN
# PLEKHN1  13.050760       -0.120418  0.394849 -0.304973  0.760387  0.929691
# PERM1     0.087781       -0.240392  1.926207 -0.124801  0.900681       NaN
# HES4     28.033269        0.181031  0.162660  1.112940  0.265734  0.653672
# ...            ...             ...       ...       ...       ...       ...
# EGFP      0.074329        0.122075  1.968420  0.062017  0.950549       NaN
# REPLI     0.357232        1.569366  1.164579  1.347582  0.177793       NaN
# GLYCO     0.263757        1.034477  1.119491  0.924060  0.355455       NaN
# MEMB      1.196666        3.134238  0.962407  3.256665  0.001127       NaN
# NUCL      0.545601        1.582431  0.757984  2.087684  0.036826       NaN
#
# [13893 rows x 6 columns]
# None
# Volcano plot of the cell type:
#
# [13893 rows x 6 columns]
# None
# Volcano plot of the cell type: Goblet cells and dpi: J3
# C:\Users\test\AppData\Local\Temp\ipykernel_17156\3859081819.py:8: DeprecationWarning: design_factors is deprecated and will soon be removed.Please consider providing a formulaic formula using the design argumentinstead.
#   dds = DeseqDataSet(
# Fitting size factors...
# ... done in 0.05 seconds.
# Using None as control genes, passed at DeseqDataSet initialization
# Fitting dispersions...
# ... done in 2.04 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.43 seconds.
#
# Fitting MAP dispersions...
# ... done in 2.71 seconds.
#
# Fitting LFCs...
# ... done in 1.56 seconds.
#
# Calculating cook's distance...
# ... done in 0.06 seconds.
#
# Replacing 13 outlier genes.
#
# Fitting dispersions...
# ... done in 0.01 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.01 seconds.
#
# Fitting LFCs...
# ... done in 0.01 seconds.
#
# Running Wald tests...
# ... done in 1.05 seconds.
# Log2 fold change & Wald test p-value: sample Inf vs Mock
#           baseMean  log2FoldChange     lfcSE      stat    pvalue      padj
# NOC2L    15.571901        0.010239  0.120101  0.085251  0.932061  0.976430
# KLHL17    2.359005        0.016079  0.277127  0.058022  0.953731  0.983930
# PLEKHN1   3.477665        0.104748  0.253806  0.412710  0.679819  0.857324
# PERM1     0.411462        0.138591  0.711640  0.194748  0.845590       NaN
# HES4     26.360387        0.161954  0.132255  1.224559  0.220741  0.508585
# ...            ...             ...       ...       ...       ...       ...
# EGFP      0.454791        1.980528  0.975254  2.030782  0.042277       NaN
# REPLI     0.927966        3.186741  1.113980  2.860681  0.004227       NaN
# GLYCO     0.309503        1.430245  1.034708  1.382269  0.166889       NaN
# MEMB      1.088536        3.438331  1.032732  3.329356  0.000870  0.015855
# NUCL      0.673291        2.587426  1.005114  2.574263  0.010045       NaN
#
# [13893 rows x 6 columns]
# None
# Volcano plot of the cell type: Goblet cells and dpi: J6
# C:\Users\test\AppData\Local\Temp\ipykernel_17156\3859081819.py:8: DeprecationWarning: design_factors is deprecated and will soon be removed.Please consider providing a formulaic formula using the design argumentinstead.
#   dds = DeseqDataSet(
# Fitting size factors...
# ... done in 0.03 seconds.
# Using None as control genes, passed at DeseqDataSet initialization
# Fitting dispersions...
# ... done in 1.90 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.46 seconds.
#
# Fitting MAP dispersions...
# ... done in 2.18 seconds.
#
# Fitting LFCs...
# ... done in 1.55 seconds.
#
# Calculating cook's distance...
# ... done in 0.03 seconds.
#
# Replacing 15 outlier genes.
#
# Fitting dispersions...
# ... done in 0.01 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.01 seconds.
#
# Fitting LFCs...
# ... done in 0.01 seconds.
#
# Running Wald tests...
# ... done in 1.06 seconds.
# Log2 fold change & Wald test p-value: sample Inf vs Mock
#          baseMean  log2FoldChange     lfcSE      stat    pvalue      padj
# NOC2L    4.824846        0.092094  0.302445  0.304498  0.760748  0.998515
# KLHL17   0.501936        1.016765  0.985212  1.032027  0.302059       NaN
# PLEKHN1  1.077153        0.659764  0.895633  0.736645  0.461338  0.998515
# PERM1    0.061990        0.101709  3.226453  0.031523  0.974852       NaN
# HES4     1.602165        0.235896  0.524295  0.449931  0.652760  0.998515
# ...           ...             ...       ...       ...       ...       ...
# EGFP     0.352052        1.374088  3.138336  0.437840  0.661503       NaN
# REPLI    0.380287        1.606372  1.843470  0.871385  0.383544       NaN
# GLYCO    0.298864        1.746345  1.831479  0.953516  0.340328       NaN
# MEMB     0.454331        2.506045  1.434590  1.746871  0.080660       NaN
# NUCL     0.808706        3.267368  1.245165  2.624045  0.008689  0.465076
#
# [13893 rows x 6 columns]
# None
# Volcano plot of the cell type: Ciliated cells and dpi: J3
# C:\Users\test\AppData\Local\Temp\ipykernel_17156\3859081819.py:8: DeprecationWarning: design_factors is deprecated and will soon be removed.Please consider providing a formulaic formula using the design argumentinstead.
#   dds = DeseqDataSet(
# Fitting size factors...
# ... done in 0.01 seconds.
# Using None as control genes, passed at DeseqDataSet initialization
# Fitting dispersions...
# ... done in 1.79 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.41 seconds.
#
# Fitting MAP dispersions...
# ... done in 2.03 seconds.
#
# Fitting LFCs...
# ... done in 1.42 seconds.
#
# Calculating cook's distance...
# ... done in 0.02 seconds.
#
# Replacing 7 outlier genes.
#
# Fitting dispersions...
# ... done in 0.01 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.01 seconds.
#
# Fitting LFCs...
# ... done in 0.01 seconds.
#
# Running Wald tests...
# ... done in 1.03 seconds.
# Log2 fold change & Wald test p-value: sample Inf vs Mock
#          baseMean  log2FoldChange     lfcSE      stat    pvalue      padj
# NOC2L    7.301965        0.260885  0.360022  0.724635  0.468676  0.947471
# KLHL17   0.904675       -0.437254  0.927612 -0.471376  0.637372       NaN
# PLEKHN1  2.149712       -1.659863  0.975337 -1.701834  0.088786       NaN
# PERM1    0.081953        0.837431  3.352263  0.249811  0.802734       NaN
# HES4     2.958897       -0.609867  0.726537 -0.839416  0.401236       NaN
# ...           ...             ...       ...       ...       ...       ...
# EGFP     0.030128        0.064563  3.340000  0.019330  0.984578       NaN
# REPLI    0.146359        1.199471  3.315121  0.361818  0.717488       NaN
# GLYCO    0.000000             NaN       NaN       NaN       NaN       NaN
# MEMB     0.000000             NaN       NaN       NaN       NaN       NaN
# NUCL     0.099312        0.425234  3.292634  0.129147  0.897241       NaN
#
# [13893 rows x 6 columns]
# None
# Volcano plot of the cell type: Ciliated cells and dpi: J6
# C:\Users\test\AppData\Local\Temp\ipykernel_17156\3859081819.py:8: DeprecationWarning: design_factors is deprecated and will soon be removed.Please consider providing a formulaic formula using the design argumentinstead.
#   dds = DeseqDataSet(
# Fitting size factors...
# ... done in 0.01 seconds.
# Using None as control genes, passed at DeseqDataSet initialization
# Fitting dispersions...
# ... done in 1.73 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.40 seconds.
#
# Fitting MAP dispersions...
# ... done in 2.00 seconds.
#
# Fitting LFCs...
# ... done in 1.75 seconds.
#
# Calculating cook's distance...
# ... done in 0.02 seconds.
#
# Replacing 0 outlier genes.
#
# Running Wald tests...
# ... done in 1.04 seconds.
# Log2 fold change & Wald test p-value: sample Inf vs Mock
#           baseMean  log2FoldChange     lfcSE      stat    pvalue      padj
# NOC2L
#
#            symbol
#  NOC2L      NOC2L
#  KLHL17    KLHL17
#  PLEKHN1  PLEKHN1
#  PERM1      PERM1
#  HES4        HES4
#  ...          ...
#  EGFP        EGFP
#  REPLI      REPLI
#  GLYCO      GLYCO
#  MEMB        MEMB
#  NUCL        NUCL
#
#  [13893 rows x 7 columns],
#  'Basal cells_J6':          baseMean  log2FoldChange     lfcSE      stat    pvalue      padj  \
#  NOC2L    3.906552        0.006636  0.515357  0.012877  0.989726  0.999959
#  KLHL17   0.946376        1.325306  1.085395  1.221036  0.222072  0.999959
#  PLEKHN1  2.200898        0.211401  0.689062  0.306796  0.758999  0.999959
#  PERM1    0.000000             NaN       NaN       NaN       NaN       NaN
#  HES4     2.753855       -0.268670  1.063723 -0.252575  0.800596  0.999959
#  ...           ...             ...       ...       ...       ...       ...
#  EGFP     0.161941        0.612865  3.109677  0.197083  0.843762  0.999959
#  REPLI    0.226055        0.749631  2.925168  0.256269  0.797743  0.999959
#  GLYCO    0.107410        0.255513  3.279623  0.077909  0.937900  0.999959
#  MEMB     0.966690        3.325720  3.133932  1.061197  0.288600  0.999959
#  NUCL     0.214820        0.614166  3.245552  0.189233  0.849910  0.999959
#
#            symbol
#  NOC2L      NOC2L
#  KLHL17    KLHL17
#  PLEKHN1  PLEKHN1
#  PERM1      PERM1
#  HES4        HES4
#  ...          ...
#  EGFP        EGFP
#  REPLI      REPLI
#  GLYCO      GLYCO
#  MEMB        MEMB
#  NUCL        NUCL
#
#  [13893 rows x 7 columns]}

# %%
pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\test\anaconda3\envs\deg\lib\site-packages (2.2.3)
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from pandas) (2025.1)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: six>=1.5 in c:\users\test\anaconda3\envs\deg\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
with pd.ExcelWriter('Deseq2_analysis.xlsx', engine='openpyxl') as writer:
    for nom, tableau in Deseq2_analysis.items():
        df = pd.DataFrame(tableau)
        df.to_excel(writer, sheet_name=nom, index=False)

# %%
fdr_threshold = 0.05
log2fc_threshold = 1
for x in Deseq2_analysis:
    Deseq2_analysis[x]['Significance'] = 'Non-significatif'
    Deseq2_analysis[x].loc[(Deseq2_analysis[x]['padj'] < fdr_threshold) & (Deseq2_analysis[x]['log2FoldChange'] > log2fc_threshold), 'Significance'] = 'Up'
    Deseq2_analysis[x].loc[(Deseq2_analysis[x]['padj'] < fdr_threshold) & (Deseq2_analysis[x]['log2FoldChange'] < -log2fc_threshold), 'Significance'] = 'Down'

    Deseq2_analysis[x]['negLogP'] = -np.log10(Deseq2_analysis[x]['padj'])

# %%
colors = {'Up': 'red', 'Down': 'blue', 'Non-significatif': 'gray'}
for x in Deseq2_analysis:
    plt.figure(figsize=(8, 6))
    sns.scatterplot(data=Deseq2_analysis[x], x="log2FoldChange", y="negLogP", hue="Significance", palette=colors, alpha=0.7)

    # Add limit lines
    plt.axhline(-np.log10(fdr_threshold), linestyle='dashed', color='black', linewidth=1)  # FDR Limit
    plt.axvline(-log2fc_threshold, linestyle='dashed', color='black', linewidth=1) 
    plt.axvline(log2fc_threshold, linestyle='dashed', color='black', linewidth=1)


    plt.xlabel("Log2(Fold Change)")
    plt.ylabel("-Log10(FDR-adjusted p-value)")
    plt.title(f"Volcano Plot of {x}")


    plt.legend(title="Genes", loc="upper right", bbox_to_anchor=(1, 1))
    plt.tight_layout()


plt.show()

# %%
with pd.ExcelWriter('Deseq2_analysis_significatif_genes.xlsx', engine='openpyxl') as writer:
    for nom, tableau in Deseq2_analysis.items():
        df = pd.DataFrame(tableau[tableau['Significance'] != 'Non-significatif'])
        df.to_excel(writer, sheet_name=nom, index=False)

# %%
#base for customized volcano plot based on what is necessary

plt.figure(figsize = (6,6))

ax = sns.scatterplot(data = df, x = 'log2FoldChange', y = 'nlog10',
                    hue = 'color', hue_order = ['nobody_cares', 'picked1', 'picked2', 'i_care'],
                    palette = ['lightgrey', 'orange', 'purple', 'grey'],
                    style = 'shape', style_order = ['picked3', 'picked4', 'not_important'],
                    markers = ['^', 's', 'o'], 
                    size = 'baseMean', sizes = (40, 400))

ax.axhline(2, zorder = 0, c = 'k', lw = 2, ls = '--')
ax.axvline(1, zorder = 0, c = 'k', lw = 2, ls = '--')
ax.axvline(-1, zorder = 0, c = 'k', lw = 2, ls = '--')



texts = []
for i in range(len(df)):
    if df.iloc[i].nlog10 > 5 and abs(df.iloc[i].log2FoldChange) > 2:
        texts.append(plt.text(x = df.iloc[i].log2FoldChange, y = df.iloc[i].nlog10, s = df.iloc[i].symbol,
                             fontsize = 12, weight = 'bold'))
        
adjust_text(texts, arrowprops = dict(arrowstyle = '-', color = 'k'))





plt.legend(loc = 1, bbox_to_anchor = (1.4,1), frameon = False, prop = {'weight':'bold'})

for axis in ['bottom', 'left']:
    ax.spines[axis].set_linewidth(2)
    
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(width = 2)

plt.xticks(size = 12, weight = 'bold')
plt.yticks(size = 12, weight = 'bold')

plt.xlabel("$log_{2}$ fold change", size = 15)
plt.ylabel("-$log_{10}$ FDR", size = 15)

plt.savefig('volcano.png', dpi = 300, bbox_inches = 'tight', facecolor = 'white')

plt.show()

# %%
de.sort_values('stat', ascending = False)
# Out:
#              baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# IFI6       188.569148        5.245403  0.444047  11.812708  3.355775e-32
# IFIT1       23.809372        4.142389  0.380142  10.896954  1.191809e-27
# ISG15       32.358044        4.269856  0.399155  10.697242  1.048529e-26
# MX1         34.807227        2.798320  0.261726  10.691786  1.112089e-26
# IFI27      146.122742        4.017119  0.379456  10.586522  3.441418e-26
# ...               ...             ...       ...        ...           ...
# TMSB15B-1    0.000000             NaN       NaN        NaN           NaN
# TRPC5OS      0.000000             NaN       NaN        NaN           NaN
# GABRQ        0.000000             NaN       NaN        NaN           NaN
# PNMA6A       0.000000             NaN       NaN        NaN           NaN
# ZFP92        0.000000             NaN       NaN        NaN           NaN
#
#                    padj
# IFI6       3.649741e-28
# IFIT1      6.481056e-24
# ISG15      3.023770e-23
# MX1        3.023770e-23
# IFI27      7.485773e-23
# ...                 ...
# TMSB15B-1           NaN
# TRPC5OS             NaN
# GABRQ               NaN
# PNMA6A              NaN
# ZFP92               NaN
#
# [13893 rows x 6 columns]

# %%
res = de[de.baseMean >= 10]

# %%
res
# Out:
#           baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# PNRC1     8.691336e-03
# MATN2     3.837985e-02
# LY6E      3.550946e-09
# IFIT3     6.812091e-17
# IFIT1     6.481056e-24
# IFITM3    2.650362e-18
# IRF7      1.452673e-07
# TRIM22    6.206789e-19
# UBE2L6    1.884382e-08
# DYNC2H1   9.859403e-03
# STAT2     2.177413e-03
# OAS1      9.782033e-19
# OAS2      1.083214e-17
# ATP12A    9.733682e-04
# IRF9      2.157660e-09
# IFI27     7.485773e-23
# EHD4      1.227007e-02
# ISG20     1.636089e-02
# N4BP1     3.991170e-02
# SLFN5     1.226708e-02
# ACOX1     4.282950e-02
# LGALS3BP  1.379391e-05
# BST2      7.346933e-10
# PLCB4     3.393037e-02
# ZNFX1     7.753775e-04
# FAM3B     4.886602e-02
# MX2       6.812091e-17
# MX1       3.023770e-23
# SCO2      2.719757e-02
# TYMP      1.354280e-03
# ODF3B     3.830877e-02

# %%
dds
# Out:
# AnnData object with n_obs × n_vars = 42 × 13893
#     obs: 'Purity', 'Cell_type', 'Compactness', 'separation', 'sample', 'dpi', 'Id'
#     uns: 'trend_coeffs', 'disp_function_type', '_squared_logres', 'prior_disp_var', 'pca', 'Id_colors'
#     obsm: 'design_matrix', 'size_factors', '_mu_LFC', '_hat_diagonals', 'replaceable', 'X_pca'
#     varm: '_normed_means', 'non_zero', '_MoM_dispersions', 'genewise_dispersions', '_genewise_converged', 'fitted_dispersions', 'MAP_dispersions', '_MAP_converged', 'dispersions', '_outlier_genes', 'LFC', '_LFC_converged', 'replaced', 'refitted', '_pvalue_cooks_outlier', 'PCs'
#     layers: 'normed_counts', '_mu_hat', 'cooks', 'replace_cooks'

# %%
dds.layers['normed_counts']
# Out:
# array([[ 0.        ,  1.65957383,  3.31914767, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 9.10265976,  1.65502905,  0.82751452, ...,  0.41375726,
#          0.        ,  0.        ],
#        [11.44652374,  0.        ,  2.86163094, ...,  2.86163094,
#          2.86163094,  8.58489281],
#        ...,
#        [ 5.91906641,  1.3659384 ,  1.3659384 , ...,  0.        ,
#          0.        ,  0.4553128 ],
#        [ 6.12888052,  0.34049336,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 3.35226654,  1.34090662,  8.0454397 , ...,  0.        ,
#          0.        ,  0.        ]])

# %%
dds.layers['log1p'] = np.log1p(dds.layers['normed_counts'].copy())

# %%
dds.layers['log1p']
# Out:
# array([[0.        , 0.9781659 , 1.46305808, ..., 0.        , 0.        ,
#         0.        ],
#        [2.31279873, 0.9764556 , 0.60295686, ..., 0.34625089, 0.        ,
#         0.        ],
#        [2.52144137, 0.        , 1.35108962, ..., 1.35108962, 1.35108962,
#         2.26018819],
#        ...,
#        [1.93428085, 0.86117473, 0.86117473, ..., 0.        , 0.        ,
#         0.37522086],
#        [1.96415421, 0.29303773, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [1.47069675, 0.8505383 , 2.20226073, ..., 0.        , 0.        ,
#         0.        ]])

# %%
dds_sigs = dds[:, sigs.index]
dds_sigs
# Out:
# View of AnnData object with n_obs × n_vars = 42 × 57
#     obs: 'Purity', 'Cell_type', 'Compactness', 'separation', 'sample', 'dpi', 'Id'
#     uns: 'trend_coeffs', 'disp_function_type', '_squared_logres', 'prior_disp_var', 'pca', 'Id_colors'
#     obsm: 'design_matrix', 'size_factors', '_mu_LFC', '_hat_diagonals', 'replaceable', 'X_pca'
#     varm: '_normed_means', 'non_zero', '_MoM_dispersions', 'genewise_dispersions', '_genewise_converged', 'fitted_dispersions', 'MAP_dispersions', '_MAP_converged', 'dispersions', '_outlier_genes', 'LFC', '_LFC_converged', 'replaced', 'refitted', '_pvalue_cooks_outlier', 'PCs'
#     layers: 'normed_counts', '_mu_hat', 'cooks', 'replace_cooks', 'log1p'

# %%
grapher = pd.DataFrame(dds_sigs.layers['log1p'].T,
                       index=dds_sigs.var_names, columns=dds_sigs.obs_names)

# %%
sns.clustermap(grapher, z_score=0, cmap = 'RdYlBu_r')
