# %% [markdown]
# # Preprocessing of RNAseq data

# %%
import scanpy as sc
import os
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
#import doubletdetection
from scipy.stats import median_abs_deviation as mad
import numpy as np

# %%
import warnings 
warnings.simplefilter("ignore", FutureWarning)
warnings.simplefilter("ignore", UserWarning)
warnings.simplefilter("ignore", RuntimeWarning)

# %% [markdown]
# # Creation of the anndata frames

# %% [markdown]
# ##### I'm using the filtered output from the 10X Genomics pipelin to generate a list of dataframes, one for each condition.

# %%
path_filtered_files_h5 = 'C:/Users/MDV/Documents/Pipeline folder Yohan/scRNA/Data/h5_files_filtered'

# %%
adatas = [x for x in os.listdir(path_filtered_files_h5 ) 
          if x.endswith('.h5')]

# %%
def load_it(adata):
    """add sample, dpi and Id columns in .obs based on the origine of the cell"""
    samp= adata.split('_')[5]
    dpi_end = adata.split('_')[6]
    dpi = dpi_end.split('.')[0]
    adata = sc.read_10x_h5(path_filtered_files_h5 + '/' + adata)
    adata.obs['Sample'] = samp
    adata.obs['dpi'] = dpi
    adata.obs['Id'] = adata.obs['Sample'] + '_' + adata.obs['dpi']
    adata.obs.index = adata.obs.index + '-' + samp + '_' + dpi

    return adata

# %%
adatas = [load_it(ad) for ad in adatas]

# %%
adatas
# Out:
# [AnnData object with n_obs × n_vars = 11004 × 18087
#      obs: 'Sample', 'dpi', 'Id'
#      var: 'gene_ids', 'feature_types', 'genome',
#  AnnData object with n_obs × n_vars = 9137 × 18087
#      obs: 'Sample', 'dpi', 'Id'
#      var: 'gene_ids', 'feature_types', 'genome',
#  AnnData object with n_obs × n_vars = 10542 × 18087
#      obs: 'Sample', 'dpi', 'Id'
#      var: 'gene_ids', 'feature_types', 'genome',
#  AnnData object with n_obs × n_vars = 8525 × 18087
#      obs: 'Sample', 'dpi', 'Id'
#      var: 'gene_ids', 'feature_types', 'genome']

# %%
for ad in adatas:
    ad.var_names_make_unique()

# %%
def qc(adata):
    # give a tag to identify Mt, ribo or hb genes
    sc.pp.filter_cells(adata, min_genes = 200)
    adata.var["mt"] = adata.var_names.str.startswith("MT-")
    adata.var["ribo"] = adata.var_names.str.startswith("RPS", "RPL")
    adata.var["hb"] = adata.var_names.str.startswith("^HB[^(P)]")
    sc.pp.calculate_qc_metrics(adata,qc_vars=["mt","ribo","hb"], inplace = True, percent_top = [20], log1p=True)

    # remove useless metrics

    remove = ['total_counts_mt', 'log1p_total_counts_mt', 'total_counts_ribo',
              'log1p_total_counts_ribo','total_counts_hb','log1p_total_counts_hb']

    adata.obs = adata.obs[[x for x in adata.obs.columns if x not in remove]]
    return adata

# %%
adatas = [qc(ad) for ad in adatas]

# %%
adatas[0].obs
# Out:
#                                   Sample dpi      Id  n_genes  \
# AAACAAGCAAGAACAAAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3     4997
# AAACAAGCACAATGGCAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3     7298
# AAACAAGCACACTAAGAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3     4357
# AAACAAGCACCGTTTGAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3     6425
# AAACAAGCACTTCGATAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3     4802
# ...                                  ...  ..     ...      ...
# TTTGTGAGTCCTTATTAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3     4338
# TTTGTGAGTCGAAGTAAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3     7765
# TTTGTGAGTGCTGATTAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3     5193
# TTTGTGAGTGTCCAATAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3     5683
# TTTGTGAGTTTCCACCAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3     4311
#
#                                    n_genes_by_counts  log1p_n_genes_by_counts  \
# AAACAAGCAAGAACAAAGTAGGCT-1-Inf_J3               4997                 8.516793
# AAACAAGCACAATGGCAGTAGGCT-1-Inf_J3               7298                 8.895493
# AAACAAGCACACTAAGAGTAGGCT-1-Inf_J3               4357                 8.379769
# AAACAAGCACCGTTTGAGTAGGCT-1-Inf_J3               6425                 8.768108
# AAACAAGCACTTCGATAGTAGGCT-1-Inf_J3               4802                 8.476996
# ...                                              ...                      ...
# TTTGTGAGTCCTTATTAGTAGGCT-1-Inf_J3               4338                 8.375399
# TTTGTGAGTCGAAGTAAGTAGGCT-1-Inf_J3               7765                 8.957511
# TTTGTGAGTGCTGATTAGTAGGCT-1-Inf_J3               5193                 8.555259
# TTTGTGAGTGTCCAATAGTAGGCT-1-Inf_J3               5683                 8.645410
# TTTGTGAGTTTCCACCAGTAGGCT-1-Inf_J3               4311                 8.369157
#
#                                    total_counts  log1p_total_counts  \
# AAACAAGCAAGAACAAAGTAGGCT-1-Inf_J3       15760.0            9.665294
# AAACAAGCACAATGGCAGTAGGCT-1-Inf_J3       36604.0           10.507940
# AAACAAGCACACTAAGAGTAGGCT-1-Inf_J3       14550.0            9.585415
# AAACAAGCACCGTTTGAGTAGGCT-1-Inf_J3       37675.0           10.536778
# AAACAAGCACTTCGATAGTAGGCT-1-Inf_J3       12024.0            9.394743
# ...                                         ...                 ...
# TTTGTGAGTCCTTATTAGTAGGCT-1-Inf_J3       12116.0            9.402365
# TTTGTGAGTCGAAGTAAGTAGGCT-1-Inf_J3       43462.0           10.679666
# TTTGTGAGTGCTGATTAGTAGGCT-1-Inf_J3       16969.0            9.739202
# TTTGTGAGTGTCCAATAGTAGGCT-1-Inf_J3       17963.0            9.796125
# TTTGTGAGTTTCCACCAGTAGGCT-1-Inf_J3       13548.0            9.514068
#
#                                    pct_counts_in_top_20_genes  pct_counts_mt  \
# AAACAAGCAAGAACAAAGTAGGCT-1-Inf_J3                   16.935279       0.158629
# AAACAAGCACAATGGCAGTAGGCT-1-Inf_J3                   22.724292       0.519069
# AAACAAGCACACTAAGAGTAGGCT-1-Inf_J3                   26.054983       0.041237
# AAACAAGCACCGTTTGAGTAGGCT-1-Inf_J3                   39.777040       0.172528
# AAACAAGCACTTCGATAGTAGGCT-1-Inf_J3                    9.971723       0.024950
# ...                                                       ...            ...
# TTTGTGAGTCCTTATTAGTAGGCT-1-Inf_J3                   21.153846       0.198085
# TTTGTGAGTCGAAGTAAGTAGGCT-1-Inf_J3                   13.416318       0.147255
# TTTGTGAGTGCTGATTAGTAGGCT-1-Inf_J3                   16.052802       0.070717
# TTTGTGAGTGTCCAATAGTAGGCT-1-Inf_J3                   20.503257       0.011134
# TTTGTGAGTTTCCACCAGTAGGCT-1-Inf_J3                   25.900502       0.354296
#
#                                    pct_counts_ribo  pct_counts_hb
# AAACAAGCAAGAACAAAGTAGGCT-1-Inf_J3              0.0            0.0
# AAACAAGCACAATGGCAGTAGGCT-1-Inf_J3              0.0            0.0
# AAACAAGCACACTAAGAGTAGGCT-1-Inf_J3              0.0            0.0
# AAACAAGCACCGTTTGAGTAGGCT-1-Inf_J3              0.0            0.0
# AAACAAGCACTTCGATAGTAGGCT-1-Inf_J3              0.0            0.0
# ...                                            ...            ...
# TTTGTGAGTCCTTATTAGTAGGCT-1-Inf_J3              0.0            0.0
# TTTGTGAGTCGAAGTAAGTAGGCT-1-Inf_J3              0.0            0.0
# TTTGTGAGTGCTGATTAGTAGGCT-1-Inf_J3              0.0            0.0
# TTTGTGAGTGTCCAATAGTAGGCT-1-Inf_J3              0.0            0.0
# TTTGTGAGTTTCCACCAGTAGGCT-1-Inf_J3              0.0            0.0
#
# [10997 rows x 12 columns]

# %%
os.makedirs('C:/Users/MDV/Documents/Pipeline folder Yohan/scRNA/Output/qc_data', exist_ok = True)

# %%
for ad in adatas:
    unique_id = ad.obs['Id'][0]
    file_path = os.path.join('C:/Users/MDV/Documents/Pipeline folder Yohan/scRNA/Output/qc_data', f'adata_{unique_id}.h5ad')
    ad.write(file_path)
    print(f"Saved: {file_path}")
# Out:
# Saved: C:/Users/MDV/Documents/Pipeline folder Yohan/scRNA/Output/qc_data\adata_Inf_J3.h5ad
# Saved: C:/Users/MDV/Documents/Pipeline folder Yohan/scRNA/Output/qc_data\adata_Inf_J6.h5ad
# Saved: C:/Users/MDV/Documents/Pipeline folder Yohan/scRNA/Output/qc_data\adata_Mock_J3.h5ad
# Saved: C:/Users/MDV/Documents/Pipeline folder Yohan/scRNA/Output/qc_data\adata_Mock_J6.h5ad

# %% [markdown]
# # scDbFinder in Rstudio

# %%
#Use the file QC R in the folder R files

# %%
# You have to use R studio and do this step there

# %% [markdown]
# # Remove the identified doublets and dead cells

# %%
path_scDbFinder_data = "C:/Users/MDV/Documents/Pipeline folder Yohan/scRNA/Output/scDbFinder_dataR"

# %%
adatas = [sc.read_h5ad(path_scDbFinder_data + '/' + x) for x in os.listdir(path_scDbFinder_data)]

# %%
adatas
# Out:
# [AnnData object with n_obs × n_vars = 10997 × 18087
#      obs: 'Sample', 'dpi', 'Id', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'doublet_score', 'doublet_class'
#      var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 9128 × 18087
#      obs: 'Sample', 'dpi', 'Id', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'doublet_score', 'doublet_class'
#      var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 10542 × 18087
#      obs: 'Sample', 'dpi', 'Id', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'doublet_score', 'doublet_class'
#      var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts',
#  AnnData object with n_obs × n_vars = 8525 × 18087
#      obs: 'Sample', 'dpi', 'Id', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'doublet_score', 'doublet_class'
#      var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts']

# %%
adatas[0].obs
# Out:
#                                   Sample dpi      Id  n_genes  \
# AAACAAGCAAGAACAAAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   4997.0
# AAACAAGCACAATGGCAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   7298.0
# AAACAAGCACACTAAGAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   4357.0
# AAACAAGCACCGTTTGAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   6425.0
# AAACAAGCACTTCGATAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   4802.0
# ...                                  ...  ..     ...      ...
# TTTGTGAGTCCTTATTAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   4338.0
# TTTGTGAGTCGAAGTAAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   7765.0
# TTTGTGAGTGCTGATTAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   5193.0
# TTTGTGAGTGTCCAATAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   5683.0
# TTTGTGAGTTTCCACCAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   4311.0
#
#                                    n_genes_by_counts  log1p_n_genes_by_counts  \
# AAACAAGCAAGAACAAAGTAGGCT-1-Inf_J3             4997.0                 8.516793
# AAACAAGCACAATGGCAGTAGGCT-1-Inf_J3             7298.0                 8.895493
# AAACAAGCACACTAAGAGTAGGCT-1-Inf_J3             4357.0                 8.379769
# AAACAAGCACCGTTTGAGTAGGCT-1-Inf_J3             6425.0                 8.768108
# AAACAAGCACTTCGATAGTAGGCT-1-Inf_J3             4802.0                 8.476996
# ...                                              ...                      ...
# TTTGTGAGTCCTTATTAGTAGGCT-1-Inf_J3             4338.0                 8.375399
# TTTGTGAGTCGAAGTAAGTAGGCT-1-Inf_J3             7765.0                 8.957511
# TTTGTGAGTGCTGATTAGTAGGCT-1-Inf_J3             5193.0                 8.555259
# TTTGTGAGTGTCCAATAGTAGGCT-1-Inf_J3             5683.0                 8.645410
# TTTGTGAGTTTCCACCAGTAGGCT-1-Inf_J3             4311.0                 8.369157
#
#                                    total_counts  log1p_total_counts  \
# AAACAAGCAAGAACAAAGTAGGCT-1-Inf_J3       15760.0            9.665294
# AAACAAGCACAATGGCAGTAGGCT-1-Inf_J3       36604.0           10.507940
# AAACAAGCACACTAAGAGTAGGCT-1-Inf_J3       14550.0            9.585415
# AAACAAGCACCGTTTGAGTAGGCT-1-Inf_J3       37675.0           10.536778
# AAACAAGCACTTCGATAGTAGGCT-1-Inf_J3       12024.0            9.394743
# ...                                         ...                 ...
# TTTGTGAGTCCTTATTAGTAGGCT-1-Inf_J3       12116.0            9.402365
# TTTGTGAGTCGAAGTAAGTAGGCT-1-Inf_J3       43462.0           10.679666
# TTTGTGAGTGCTGATTAGTAGGCT-1-Inf_J3       16969.0            9.739202
# TTTGTGAGTGTCCAATAGTAGGCT-1-Inf_J3       17963.0            9.796125
# TTTGTGAGTTTCCACCAGTAGGCT-1-Inf_J3       13548.0            9.514068
#
#                                    pct_counts_in_top_20_genes  pct_counts_mt  \
# AAACAAGCAAGAACAAAGTAGGCT-1-Inf_J3                   16.935279       0.158629
# AAACAAGCACAATGGCAGTAGGCT-1-Inf_J3                   22.724292       0.519069
# AAACAAGCACACTAAGAGTAGGCT-1-Inf_J3                   26.054983       0.041237
# AAACAAGCACCGTTTGAGTAGGCT-1-Inf_J3                   39.777040       0.172528
# AAACAAGCACTTCGATAGTAGGCT-1-Inf_J3                    9.971723       0.024950
# ...                                                       ...            ...
# TTTGTGAGTCCTTATTAGTAGGCT-1-Inf_J3                   21.153846       0.198085
# TTTGTGAGTCGAAGTAAGTAGGCT-1-Inf_J3                   13.416318       0.147255
# TTTGTGAGTGCTGATTAGTAGGCT-1-Inf_J3                   16.052802       0.070717
# TTTGTGAGTGTCCAATAGTAGGCT-1-Inf_J3                   20.503257       0.011134
# TTTGTGAGTTTCCACCAGTAGGCT-1-Inf_J3                   25.900502       0.354296
#
#                                    pct_counts_ribo  pct_counts_hb  \
# AAACAAGCAAGAACAAAGTAGGCT-1-Inf_J3              0.0            0.0
# AAACAAGCACAATGGCAGTAGGCT-1-Inf_J3              0.0            0.0
# AAACAAGCACACTAAGAGTAGGCT-1-Inf_J3              0.0            0.0
# AAACAAGCACCGTTTGAGTAGGCT-1-Inf_J3              0.0            0.0
# AAACAAGCACTTCGATAGTAGGCT-1-Inf_J3              0.0            0.0
# ...                                            ...            ...
# TTTGTGAGTCCTTATTAGTAGGCT-1-Inf_J3              0.0            0.0
# TTTGTGAGTCGAAGTAAGTAGGCT-1-Inf_J3              0.0            0.0
# TTTGTGAGTGCTGATTAGTAGGCT-1-Inf_J3              0.0            0.0
# TTTGTGAGTGTCCAATAGTAGGCT-1-Inf_J3              0.0            0.0
# TTTGTGAGTTTCCACCAGTAGGCT-1-Inf_J3              0.0            0.0
#
#                                    doublet_score doublet_class
# AAACAAGCAAGAACAAAGTAGGCT-1-Inf_J3       0.004295       singlet
# AAACAAGCACAATGGCAGTAGGCT-1-Inf_J3       0.999850       doublet
# AAACAAGCACACTAAGAGTAGGCT-1-Inf_J3       0.002755       singlet
# AAACAAGCACCGTTTGAGTAGGCT-1-Inf_J3       0.149686       singlet
# AAACAAGCACTTCGATAGTAGGCT-1-Inf_J3       0.000124       singlet
# ...                                          ...           ...
# TTTGTGAGTCCTTATTAGTAGGCT-1-Inf_J3       0.004089       singlet
# TTTGTGAGTCGAAGTAAGTAGGCT-1-Inf_J3       0.999401       doublet
# TTTGTGAGTGCTGATTAGTAGGCT-1-Inf_J3       0.000517       singlet
# TTTGTGAGTGTCCAATAGTAGGCT-1-Inf_J3       0.024200       singlet
# TTTGTGAGTTTCCACCAGTAGGCT-1-Inf_J3       0.027058       singlet
#
# [10997 rows x 14 columns]

# %%
def mad_outlier(adata, metric, nmads, upper_only = False):
    M = adata.obs[metric]
    
    if not upper_only:
        return (M < np.median(M) - nmads * mad(M)) | (M > np.median(M) + nmads * mad(M))
    
    return (M > np.median(M) + nmads * mad(M))

# %%
#clf = doubletdetection.BoostClassifier(
#    n_iters=10,
#    clustering_algorithm="louvain",
#    standard_scaling=True,
#    pseudocount=0.1,
#    n_jobs=-1)

# %%
def pp(adata):
    adata = adata[adata.obs.pct_counts_mt < 6] 
    
    bool_vector = mad_outlier(adata, 'log1p_total_counts', 5) +\
            mad_outlier(adata, 'log1p_n_genes_by_counts', 5) +\
            mad_outlier(adata, 'pct_counts_in_top_20_genes', 5) +\
            mad_outlier(adata, 'pct_counts_mt', 3, upper_only = True)
    adata = adata[~bool_vector]

    adata.uns['cells_removed'] = sum(bool_vector)

    #doublets = clf.fit(adata.X).predict(p_thresh=1e-16, voter_thresh=0.5)
    #doublet_score = clf.doublet_score()

    #adata.obs["doublet_dbd"] = doublets
    #adata.obs["doublet_score_dbd"] = doublet_score

    #adata.uns['doublets_removed_dbd'] = adata.obs.doublet_dbd.sum()
    #adata = adata[adata.obs.doublet_dbd == 0]
    #adata = adata[adata.obs.doublet_class_scDbFinder == 0]

    return adata

# %%
adatas = [pp(ad) for ad in adatas]

# %%
for adata in adatas:
    print(len(adata),adata.obs.doublet_class.value_counts())
# Out:
# 8699 doublet_class
# singlet    7260
# doublet    1439
# Name: count, dtype: int64
# 7287 doublet_class
# singlet    6213
# doublet    1074
# Name: count, dtype: int64
# 8057 doublet_class
# singlet    6847
# doublet    1210
# Name: count, dtype: int64
# 6805 doublet_class
# singlet    5863
# doublet     942
# Name: count, dtype: int64

# %%
adatas[0][adatas[0].obs.doublet_class == 'singlet'].obs
# Out:
#                                   Sample dpi      Id  n_genes  \
# AAACAAGCAAGAACAAAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   4997.0
# AAACAAGCACACTAAGAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   4357.0
# AAACAAGCACCGTTTGAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   6425.0
# AAACAAGCACTTCGATAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   4802.0
# AAACAAGCATGGTCAAAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   4699.0
# ...                                  ...  ..     ...      ...
# TTTGGCGGTGATCCTGAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   3204.0
# TTTGTGAGTCCTTATTAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   4338.0
# TTTGTGAGTGCTGATTAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   5193.0
# TTTGTGAGTGTCCAATAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   5683.0
# TTTGTGAGTTTCCACCAGTAGGCT-1-Inf_J3    Inf  J3  Inf_J3   4311.0
#
#                                    n_genes_by_counts  log1p_n_genes_by_counts  \
# AAACAAGCAAGAACAAAGTAGGCT-1-Inf_J3             4997.0                 8.516793
# AAACAAGCACACTAAGAGTAGGCT-1-Inf_J3             4357.0                 8.379769
# AAACAAGCACCGTTTGAGTAGGCT-1-Inf_J3             6425.0                 8.768108
# AAACAAGCACTTCGATAGTAGGCT-1-Inf_J3             4802.0                 8.476996
# AAACAAGCATGGTCAAAGTAGGCT-1-Inf_J3             4699.0                 8.455318
# ...                                              ...                      ...
# TTTGGCGGTGATCCTGAGTAGGCT-1-Inf_J3             3204.0                 8.072467
# TTTGTGAGTCCTTATTAGTAGGCT-1-Inf_J3             4338.0                 8.375399
# TTTGTGAGTGCTGATTAGTAGGCT-1-Inf_J3             5193.0                 8.555259
# TTTGTGAGTGTCCAATAGTAGGCT-1-Inf_J3             5683.0                 8.645410
# TTTGTGAGTTTCCACCAGTAGGCT-1-Inf_J3             4311.0                 8.369157
#
#                                    total_counts  log1p_total_counts  \
# AAACAAGCAAGAACAAAGTAGGCT-1-Inf_J3       15760.0            9.665294
# AAACAAGCACACTAAGAGTAGGCT-1-Inf_J3       14550.0            9.585415
# AAACAAGCACCGTTTGAGTAGGCT-1-Inf_J3       37675.0           10.536778
# AAACAAGCACTTCGATAGTAGGCT-1-Inf_J3       12024.0            9.394743
# AAACAAGCATGGTCAAAGTAGGCT-1-Inf_J3       15655.0            9.658609
# ...                                         ...                 ...
# TTTGGCGGTGATCCTGAGTAGGCT-1-Inf_J3        6884.0            8.837100
# TTTGTGAGTCCTTATTAGTAGGCT-1-Inf_J3       12116.0            9.402365
# TTTGTGAGTGCTGATTAGTAGGCT-1-Inf_J3       16969.0            9.739202
# TTTGTGAGTGTCCAATAGTAGGCT-1-Inf_J3       17963.0            9.796125
# TTTGTGAGTTTCCACCAGTAGGCT-1-Inf_J3       13548.0            9.514068
#
#                                    pct_counts_in_top_20_genes  pct_counts_mt  \
# AAACAAGCAAGAACAAAGTAGGCT-1-Inf_J3                   16.935279       0.158629
# AAACAAGCACACTAAGAGTAGGCT-1-Inf_J3                   26.054983       0.041237
# AAACAAGCACCGTTTGAGTAGGCT-1-Inf_J3                   39.777040       0.172528
# AAACAAGCACTTCGATAGTAGGCT-1-Inf_J3                    9.971723       0.024950
# AAACAAGCATGGTCAAAGTAGGCT-1-Inf_J3                   23.027787       0.229958
# ...                                                       ...            ...
# TTTGGCGGTGATCCTGAGTAGGCT-1-Inf_J3                   15.862870       0.203370
# TTTGTGAGTCCTTATTAGTAGGCT-1-Inf_J3                   21.153846       0.198085
# TTTGTGAGTGCTGATTAGTAGGCT-1-Inf_J3                   16.052802       0.070717
# TTTGTGAGTGTCCAATAGTAGGCT-1-Inf_J3                   20.503257       0.011134
# TTTGTGAGTTTCCACCAGTAGGCT-1-Inf_J3                   25.900502       0.354296
#
#                                    pct_counts_ribo  pct_counts_hb  \
# AAACAAGCAAGAACAAAGTAGGCT-1-Inf_J3              0.0            0.0
# AAACAAGCACACTAAGAGTAGGCT-1-Inf_J3              0.0            0.0
# AAACAAGCACCGTTTGAGTAGGCT-1-Inf_J3              0.0            0.0
# AAACAAGCACTTCGATAGTAGGCT-1-Inf_J3              0.0            0.0
# AAACAAGCATGGTCAAAGTAGGCT-1-Inf_J3              0.0            0.0
# ...                                            ...            ...
# TTTGGCGGTGATCCTGAGTAGGCT-1-Inf_J3              0.0            0.0
# TTTGTGAGTCCTTATTAGTAGGCT-1-Inf_J3              0.0            0.0
# TTTGTGAGTGCTGATTAGTAGGCT-1-Inf_J3              0.0            0.0
# TTTGTGAGTGTCCAATAGTAGGCT-1-Inf_J3              0.0            0.0
# TTTGTGAGTTTCCACCAGTAGGCT-1-Inf_J3              0.0            0.0
#
#                                    doublet_score doublet_class
# AAACAAGCAAGAACAAAGTAGGCT-1-Inf_J3       0.004295       singlet
# AAACAAGCACACTAAGAGTAGGCT-1-Inf_J3       0.002755       singlet
# AAACAAGCACCGTTTGAGTAGGCT-1-Inf_J3       0.149686       singlet
# AAACAAGCACTTCGATAGTAGGCT-1-Inf_J3       0.000124       singlet
# AAACAAGCATGGTCAAAGTAGGCT-1-Inf_J3       0.000208       singlet
# ...                                          ...           ...
# TTTGGCGGTGATCCTGAGTAGGCT-1-Inf_J3       0.000439       singlet
# TTTGTGAGTCCTTATTAGTAGGCT-1-Inf_J3       0.004089       singlet
# TTTGTGAGTGCTGATTAGTAGGCT-1-Inf_J3       0.000517       singlet
# TTTGTGAGTGTCCAATAGTAGGCT-1-Inf_J3       0.024200       singlet
# TTTGTGAGTTTCCACCAGTAGGCT-1-Inf_J3       0.027058       singlet
#
# [7260 rows x 14 columns]

# %%
def filter_doublets(adata):
    adata = adata[adata.obs.doublet_class == 'singlet']
    return adata

# %%
adatas = [filter_doublets(ad) for ad in adatas]

# %%
adatas
# Out:
# [View of AnnData object with n_obs × n_vars = 7260 × 18087
#      obs: 'Sample', 'dpi', 'Id', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'doublet_score', 'doublet_class'
#      var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#      uns: 'cells_removed',
#  View of AnnData object with n_obs × n_vars = 6213 × 18087
#      obs: 'Sample', 'dpi', 'Id', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'doublet_score', 'doublet_class'
#      var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#      uns: 'cells_removed',
#  View of AnnData object with n_obs × n_vars = 6847 × 18087
#      obs: 'Sample', 'dpi', 'Id', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'doublet_score', 'doublet_class'
#      var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#      uns: 'cells_removed',
#  View of AnnData object with n_obs × n_vars = 5863 × 18087
#      obs: 'Sample', 'dpi', 'Id', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'pct_counts_mt', 'pct_counts_ribo', 'pct_counts_hb', 'doublet_score', 'doublet_class'
#      var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#      uns: 'cells_removed']

# %%
os.makedirs('C:/Users/MDV/Documents/Pipeline folder Yohan/scRNA/Output/processed_data', exist_ok = True)

# %%
for ad in adatas:
    unique_id = ad.obs['Id'][0]
    file_path = os.path.join('C:/Users/MDV/Documents/Pipeline folder Yohan/scRNA/Output/processed_data', f'adata_{unique_id}.h5ad')
    ad.write(file_path)
    print(f"Saved: {file_path}")
# Out:
# Saved: C:/Users/MDV/Documents/Pipeline folder Yohan/scRNA/Output/processed_data\adata_Inf_J3.h5ad
# Saved: C:/Users/MDV/Documents/Pipeline folder Yohan/scRNA/Output/processed_data\adata_Inf_J6.h5ad
# Saved: C:/Users/MDV/Documents/Pipeline folder Yohan/scRNA/Output/processed_data\adata_Mock_J3.h5ad
# Saved: C:/Users/MDV/Documents/Pipeline folder Yohan/scRNA/Output/processed_data\adata_Mock_J6.h5ad
